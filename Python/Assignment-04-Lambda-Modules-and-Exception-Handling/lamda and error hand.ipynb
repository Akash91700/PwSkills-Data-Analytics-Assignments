# %% [markdown]
# # Easy Level

# %% [markdown]
# **ANSWER = 1**

# %% [markdown]
# In Python, a lambda function is a small, anonymous function defined using the lambda keyword. It can take any number of arguments but has only one expression.

# %% [markdown]
# **Syntax:**
#
# * lambda arguments: expression

# %% [markdown]
#  Why Lambda Functions Are Useful
# - Concise and Readable
# Lambda functions let you write quick, throwaway functions in a single line—perfect for simple operations like sorting, filtering, or mapping.
# - Great for Functional Programming
# They're often used with functions like map(), filter(), and sorted() to apply logic inline without defining a full function.
# Would you like to see some real-world examples using lambda with map() or filter()?

# %% [markdown]
# **ANSWER = 2**

# %%
square = lambda x: x * x

# %%
print(square(5))
# Out:
# 25

# %% [markdown]
# **ANSWER = 3**

# %%
import math              # Import the math module to access mathematical constants and functions

print(math.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# # Medium Level

# %% [markdown]
# **ANSWER = 4**

# %%
numbers = [2, 4, 6, 8]                           # List of numbers to be doubled
doubled = list(map(lambda x: x * 2, numbers))  # lambda takes x and returns x*2

print(doubled)
# Out:
# [4, 8, 12, 16]

# %% [markdown]
# **ANSWER = 5**

# %%
num1 = int(input("Enter the first number: "))   
num2 = int(input("Enter the second number: "))    
try:
    result = num1 / num2                          # Attempt to divide num1 by num2
    print("Result:", result)                      
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
# Out:
# Error: Cannot divide by zero!

# %% [markdown]
# **ANSWER = 6**

# %%
import random                      # Import the random module to use random number functions

number = random.randint(1, 10)     # Generate a random integer between 1 and 10 (inclusive)

print("Random number:", number)
# Out:
# Random number: 3

# %% [markdown]
# # Hard Level

# %% [markdown]
# **ANSWER = 7**

# %%
numbers = [3, 6, 9, 12, 15, 18]                 
                 
# Use filter() with a lambda function to extract even numbers
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))          # Keep numbers where remainder when divided by 2 is 0
print("Even numbers:", even_numbers)
# Out:
# Even numbers: [6, 12, 18]

# %% [markdown]
# **ANSWER = 8**

# %%
try:
    # Take two inputs from the user
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    # Try dividing
    result = num1 / num2
    print("Result:", result)

except ValueError:
    print("Error: Invalid input. Please enter numbers only.")
    print("Error: Cannot divide by zero.")
except ZeroDivisionError:
    print("Error: Invalid input. Please enter numbers only.")
    print("Error: Cannot divide by zero.")
# Out:
# Error: Invalid input. Please enter numbers only.
# Error: Cannot divide by zero.
